# %% [markdown]
# # Investigation of Drug Use and Drug-Positive Crash Risk in the US

# %% [markdown]
# ## INTRODUCTION
# This project investigates drug habits and drug-positive crash risk of people in the US. The overall goal of this analysis was to determine how drug use rates and drug-positive crash risk are related between different age groups. Many more specific hypotheses were considered in order to inform on this overall question. First, I examined the most recent data available (from 2018) to determine if the drug use rates of three age groups were statistically different from each other at this time. Second, I looked specifically at which drug was most likely to be used by various age groups. Third, I determined which drugs were most frequently found in crash drivers and which age group of people were most likely to get into a crash while drug-positive.
#
# Two datasets are used to perform this analysis. The first is on substance use in the US overtime in different age groups. This data was reported by the National Survey on Drug Use and Health (NSDUH) between 2002-2018. This dataset was used to compare drug use in 3 ages groups from 2010 to 2018. The second dataset is on crash risk of drug-positive drivers. This data was reported by the National Highway Traffic Safety Administration (NHTSA). This dataset was used to determine which drugs were most common in crash drivers and which age group had the highest crash risk.
#
# Drunk and drugged driving is a devastating issue in the US, so I thought it would be interesting to see how exactly different age groups have contributed to this problem. What age group has the highest rate of drug use? The highest rate of drug-positive crashes? Comparing these values will allow me to investigate the relationship between age, drug use, and drug-positive crash risk. The results of this analysis will inform on which population of people in the US are most prone to impaired car accidents.
#
# Datasets:
# <li> https://think.cs.vt.edu/corgis/csv/drugs/
# <li> https://www.nhtsa.gov/drug-and-alcohol-crash-risk-study/drug-and-alcohol-crash-risk-study-databases

# %% [markdown]
# ## DATA ORGANIZATION

# %%
# importing needed libraries 
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import math

# %%
# loading datasets 
drugUse = pd.read_csv('/Users/CatLeal/Documents/UT/S5/NEU340/NEU340_Python/Final Project/drug-use-by-state.csv')
crashRisk = pd.read_csv('/Users/CatLeal/Documents/UT/S5/NEU340/NEU340_Python/Final Project/drug-crash-risk.csv')
# Out:
# /var/folders/8y/9d3sn3bs31q01_vp3wj1dzyw0000gn/T/ipykernel_10105/2905069586.py:3: DtypeWarning: Columns (120,133,158,167,170,181,191,200,210,232,233,261,265,268,272,276,279,280,313,315,316,318,320,328) have mixed types. Specify dtype option on import or set low_memory=False.
#   crashRisk = pd.read_csv('/Users/CatLeal/Documents/UT/S5/NEU340/NEU340_Python/Final Project/drug-crash-risk.csv')

# %% [markdown]
# ### Dataset 1 on Drug Use in the US Over Time
# <li> Although data is available from 2002-2018, only data from 2010-2018 will be analyzed in order to keep this section as concise as possible.

# %%
# each year for which data was recorded which we will analyze 
years = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]) 
# the age groups for which data was collected 
ageGroups = ['12-17', '18-25', '26+']

# alcohol usage in 12-17 year olds in the US, per year 2010-2018
alcoholG1Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
alcoholG1Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Alcohol.Use Disorder Past Year.12-17']) * 1000
# array of 12-17 year old alcohol use over time 
alcoholG1 = np.array([alcoholG1Y2010, alcoholG1Y2011, alcoholG1Y2012, alcoholG1Y2013, alcoholG1Y2014, \
    alcoholG1Y2015, alcoholG1Y2016, alcoholG1Y2017, alcoholG1Y2018])

# alcohol usage in 18-25 year olds in the US, per year 2010-2018
alcoholG2Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
alcoholG2Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Alcohol.Use Disorder Past Year.18-25']) * 1000
# array of 18-25 year old alcohol use over time 
alcoholG2 = np.array([alcoholG2Y2010, alcoholG2Y2011, alcoholG2Y2012, alcoholG2Y2013, alcoholG2Y2014, \
    alcoholG2Y2015, alcoholG2Y2016, alcoholG2Y2017, alcoholG2Y2018])

# alcohol usage in 26+ year olds in the US, per year 2010-2018
alcoholG3Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
alcoholG3Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Alcohol.Use Disorder Past Year.26+']) * 1000
# array of 26+ year old alcohol use over time 
alcoholG3 = np.array([alcoholG3Y2010, alcoholG3Y2011, alcoholG3Y2012, alcoholG3Y2013, alcoholG3Y2014, \
    alcoholG3Y2015, alcoholG3Y2016, alcoholG3Y2017, alcoholG3Y2018])

# cocaine usage in 12-17 year olds in the US, per year 2010-2018
cocaineG1Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
cocaineG1Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Illicit Drugs.Cocaine Used Past Year.12-17']) * 1000
# array of 12-17 year old cocaine use over time 
cocaineG1 = np.array([cocaineG1Y2010, cocaineG1Y2011, cocaineG1Y2012, cocaineG1Y2013, cocaineG1Y2014, \
    cocaineG1Y2015, cocaineG1Y2016, cocaineG1Y2017, cocaineG1Y2018])

# cocaine usage in 18-25 year olds in the US, per year 2010-2018
cocaineG2Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
cocaineG2Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Illicit Drugs.Cocaine Used Past Year.18-25']) * 1000
# array of 18-25 year old cocaine use over time 
cocaineG2 = np.array([cocaineG2Y2010, cocaineG2Y2011, cocaineG2Y2012, cocaineG2Y2013, cocaineG2Y2014, \
    cocaineG2Y2015, cocaineG2Y2016, cocaineG2Y2017, cocaineG2Y2018])

# cocaine usage in 26+ year olds in the US, per year 2010-2018
cocaineG3Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
cocaineG3Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Illicit Drugs.Cocaine Used Past Year.26+']) * 1000
# array of 26+ year old cocaine use over time 
cocaineG3 = np.array([cocaineG3Y2010, cocaineG3Y2011, cocaineG3Y2012, cocaineG3Y2013, cocaineG3Y2014, \
    cocaineG3Y2015, cocaineG3Y2016, cocaineG3Y2017, cocaineG3Y2018])

# marijuana usage in 12-17 year olds in the US, per year 2010-2018
marijuanaG1Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Marijuana.Used Past Year.12-17']) * 1000
marijuanaG1Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Marijuana.Used Past Year.12-17']) * 1000
# array of 12-17 year olds marijuana use over time 
marijuanaG1 = np.array([marijuanaG1Y2010, marijuanaG1Y2011, marijuanaG1Y2012, marijuanaG1Y2013, marijuanaG1Y2014, \
    marijuanaG1Y2015, marijuanaG1Y2016, marijuanaG1Y2017, marijuanaG1Y2018])

# marijuana usage in 18-25 year olds in the US, per year 2010-2018
marijuanaG2Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG2Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Marijuana.Used Past Year.18-25']) * 1000
# array of 18-25 year olds marijuana use over time 
marijuanaG2 = np.array([marijuanaG2Y2010, marijuanaG2Y2011, marijuanaG2Y2012, marijuanaG2Y2013, marijuanaG2Y2014, \
    marijuanaG2Y2015, marijuanaG2Y2016, marijuanaG2Y2017, marijuanaG2Y2018])

# marijuana usage in 26+ year olds in the US, per year 2010-2018
marijuanaG3Y2010 = sum(drugUse[drugUse['Year'] == 2010]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2011 = sum(drugUse[drugUse['Year'] == 2011]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2012 = sum(drugUse[drugUse['Year'] == 2012]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2013 = sum(drugUse[drugUse['Year'] == 2013]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2014 = sum(drugUse[drugUse['Year'] == 2014]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2015 = sum(drugUse[drugUse['Year'] == 2015]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2016 = sum(drugUse[drugUse['Year'] == 2016]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2017 = sum(drugUse[drugUse['Year'] == 2017]['Totals.Marijuana.Used Past Year.18-25']) * 1000
marijuanaG3Y2018 = sum(drugUse[drugUse['Year'] == 2018]['Totals.Marijuana.Used Past Year.18-25']) * 1000
# array of 26+ year olds marijuana use over time 
marijuanaG3 = np.array([marijuanaG3Y2010, marijuanaG3Y2011, marijuanaG3Y2012, marijuanaG3Y2013, marijuanaG3Y2014, \
    marijuanaG3Y2015, marijuanaG3Y2016, marijuanaG3Y2017, marijuanaG3Y2018])

## data to be used for bootstrapping
# list of percents of alcohol users in each state for each age group
alcoholPercentsG1 = list(drugUse[drugUse['Year'] == 2018]['Rates.Alcohol.Use Disorder Past Year.12-17'])
alcoholPercentsG2 = list(drugUse[drugUse['Year'] == 2018]['Rates.Alcohol.Use Disorder Past Year.18-25'])
alcoholPercentsG3 = list(drugUse[drugUse['Year'] == 2018]['Rates.Alcohol.Use Disorder Past Year.26+'])
# list of percents of cocaine users in each state for each age group
cocainePercentsG1 = list(drugUse[drugUse['Year'] == 2018]['Rates.Illicit Drugs.Cocaine Used Past Year.12-17'])
cocainePercentsG2 = list(drugUse[drugUse['Year'] == 2018]['Rates.Illicit Drugs.Cocaine Used Past Year.18-25'])
cocainePercentsG3 = list(drugUse[drugUse['Year'] == 2018]['Rates.Illicit Drugs.Cocaine Used Past Year.26+'])
# list of percents of marijuana users in each state for each age group
marijuanaPercentsG1 = list(drugUse[drugUse['Year'] == 2018]['Rates.Marijuana.Used Past Year.12-17'])
marijuanaPercentsG2 = list(drugUse[drugUse['Year'] == 2018]['Rates.Marijuana.Used Past Year.18-25'])
marijuanaPercentsG3 = list(drugUse[drugUse['Year'] == 2018]['Rates.Marijuana.Used Past Year.26+'])
# all percents for all drugs per group 
percentsG1 = alcoholPercentsG1 + cocainePercentsG1 + marijuanaPercentsG1
percentsG2 = alcoholPercentsG2 + cocainePercentsG2 + marijuanaPercentsG2
percentsG3 = alcoholPercentsG3 + cocainePercentsG3 + marijuanaPercentsG3
# proportion virtual lists based on data (0 = not a user, 1 = user) - to be bootstrapped
virtualG1 = []
virtualG2 = []
virtualG3 = []
for ii in range(153): 
    # number of users per group per 10,000 people
    numUsersG1 = math.ceil(percentsG1[ii] * 100)
    numUsersG2 = math.ceil(percentsG2[ii] * 100)
    numUsersG3 = math.ceil(percentsG3[ii] * 100)
    # temporary proportion lists representing rates in each state per drug 
    temp1 = [0] * 10000
    temp2 = [0] * 10000
    temp3 = [0] * 10000
    # changing number-of-users amount of elements to 1, then add temp list to appropriate virtual array
    for num in range(numUsersG1):
        temp1[num] = 1
    virtualG1 += temp1 
    for num in range(numUsersG2):
        temp2[num] = 1
    virtualG2 += temp2
    for num in range(numUsersG3):
        temp3[num] = 1
    virtualG3 += temp3
# number of people per age group (per 1,530,000 people) who use some drug in 2018
countG1 = sum(virtualG1) 
countG2 = sum(virtualG2) 
countG3 = sum(virtualG3)

# %% [markdown]
# ### Dataset 2 on a Drug-Positive Crash Risk Study

# %%
numCrashes = len(crashRisk['casenum'].unique()) # the total number of crashes 
possibleDrugs = crashRisk['drug_name_of'].unique() # list of drugs reported in crash drivers 
possibleDrugs = np.delete(possibleDrugs, [1,2]) # removing drug-negative entries 

drugPositiveCaseNums = [] # case numbers of crashes involving a drug-positive driver 
for ii in range(1, (numCrashes+1)):
    singleCrash = crashRisk[crashRisk['casenum'] == ii] # subset of a single crash instance 
    drugContents = singleCrash['drug_name_of'] # drug influence of each driver involved in the crash 
    drugPositive = False # flag indicating if the crash involved a drug-positive driver 
    for jj in drugContents:
        if jj in possibleDrugs: 
            drugPositive = True # change flag to True if drug contents of a single driver was positive 
    if drugPositive:
        drugPositiveCaseNums.append(ii) # add case number to list of drug-positive case numbers 

drugPositiveCrashes = [] # list of dataframes containing drug-positive crashes
for caseNum in drugPositiveCaseNums:
    crash = pd.DataFrame(crashRisk[crashRisk['casenum'] == caseNum]) # dataframe on individual crash (may contain 2+ drivers)
    drugPositiveCrashes.append(crash) # add individual crash data to drug-positive crash list 
    
drugPositiveDrivers = [] # list of dataframes for drug-positive drivers 
for case in drugPositiveCrashes:
    drugUses = list(case['drug_name_of']) # list of drug use of all drivers involved in crash
    for ii in range(len(drugUses)):
        drug = drugUses[ii] # drug content of individual driver 
        if drug in possibleDrugs: # filtering for drug-positive drivers 
            drugPositiveDrivers.append(case[case['drug_name_of'] == drug]) # adding individual driver data to list 

drugsPosDrivers = [] # list of drugs found in drug positive-drivers
for driver in drugPositiveDrivers:
    drugsPosDrivers += list(driver['drug_name_of']) # add specific driver's drug influence to list 
uniqueDrugs, drugCounts = np.unique(drugsPosDrivers, return_counts = True) # unique drugs and their frequencies 

# identifying drug frequencies less than 13 
delete_idxs = []
for ii in range(len(uniqueDrugs)):
    if drugCounts[ii] < 13:
        delete_idxs.append(ii)
# deleting drug frequencies less than 13 to simplify plot 
uniqueDrugs = np.delete(uniqueDrugs, delete_idxs)
drugCounts = np.delete(drugCounts, delete_idxs)

bac_results = [] # blood alcohol content of drug positive drivers  
for ii in range(len(drugPositiveDrivers)):
    driver = drugPositiveDrivers[ii]
    bac_results += list(driver['pbt_result']) # adding bac result of each driver to list 
# removing null values 
null_count = bac_results.count('#NULL!')
for ii in range(null_count):
    bac_results.remove('#NULL!')
# count frequency of bac > 0 
bacPositiveCount = 0 # initializing count of intoxicated drivers 
for ii in range(len(bac_results)):
    if float(bac_results[ii]) > 0.0: # increase count if driver's bac > 0 
        bacPositiveCount += 1
# adding alcohol frequency to arrays
uniqueDrugs = np.append(uniqueDrugs, np.array('Alcohol'))
drugCounts = np.append(drugCounts, np.array(bacPositiveCount))

ages = [] # list of age groups for drug-positive drivers 
for ii in range(len(drugPositiveDrivers)):
    driver = drugPositiveDrivers[ii]
    ages += list(driver['estimate_driverage']) # adding driver's age range to list 
# frequency values for each age group 
G1Count = ages.count(1.0)
G2Count = ages.count(2.0)
G3Count = ages.count(3.0)
G4Count = ages.count(4.0)
ageGroups2 = ['16-20','21-34','35-64','65+'] # list of age groups 
ageGroupCounts = [G1Count, G2Count, G3Count, G4Count] # list of age group frequencies

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# ### How did total substance use per age group compare in 2018?
# Hypothesis: 18-25 year olds had the highest rate of substance use in 2018.
#
# Note that plotting values which are ratios of users to 1,530,000 people allows the rates of use to be directly compared, despite the fact that these age groups have different populations.

# %%
# per-group substance use comparison in 2018
fig = plt.figure(figsize=(8,4)) # initializing plot 
plt.bar(x=ageGroups, height=[countG1, countG2, countG3], color='darkblue') # displayed in bar graph 
plt.title('Total Substance Users Per 1,530,000 People Within An Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Users Per 1,530,000 People')
# Out:
# Text(0, 0.5, 'Number of Users Per 1,530,000 People')

# %% [markdown]
# FIGURE 1: The above plot compares the number of substance users in 2018 in each age group per about 1.5 million people. An example interpretation would be that for about every 1.5 million 12-17 year olds in the US in 2018, about 900 of them were drug users in 2018.

# %% [markdown]
# ### Is the rate of drug use for the 18-25 age group statistically different from the rates of use for the other two age groups?
# It was determined from Figure 1 that 18-25 year olds had the highest rate of substance use in 2018. Now, a bootstrap analysis will be performed on the other two age groups' data to determine if the drug use ratio of 18-25 year olds could come from the distributions of the other age groups.
#
# Hypothesis: The ratio of use for 18-25 year olds in 2018 was significantly higher than the ratios of use for the other age groups.

# %%
## methods to be used to perform a bootstrap analysis 
def bootstrap(data, num): # bootstrapping method 
    samples = np.zeros(num) # empty array to be filled with sample counts 
    for ii in range(num): 
        # chooses sample from data with replacement
        sample = np.random.choice(data, size=len(data), replace=True) 
        count = np.sum(sample) # counts number of 1s in sample 
        samples[ii] = count # saves sample count to array 
    return samples # returns array of counts 

def confidenceIntervals(dataArray,pValue=0.05): # method to get exact confidence interval  
    sorted = np.sort(dataArray) # sort array 
    lowIndex = int((pValue/2)*len(sorted))-1  # get low end cut-off value
    highIndex = int((1-(pValue/2))*len(sorted))-1   # get high end cut-off value
    return sorted[lowIndex], sorted[highIndex] # returns exact cut-off values 

def tailsHisto(d1, binWidth, pValue, ageGroup): # function to graph bootstrapped data with confidence interval
    nB = len(d1)
    (n, bins, p) = plt.hist(d1, bins=np.arange(min(d1), max(d1) + binWidth, binWidth), edgecolor = 'black') # plot in histogram 
    sum = 0
    for i in range(0,len(p)): # changing color of out of confidence interval values 
        sum += n[i]
        if sum < nB*(pValue/2): 
            p[i].set(color = 'r')
            p[i].set(edgecolor='black')
        if sum > nB*(1-(pValue/2)): 
            p[i].set(color = 'r')
            p[i].set(edgecolor='black')
    plt.ylabel('Frequency')
    plt.xlabel('Sample Ratio of Users Per 1,530,000 People')
    plt.title(('Bootstrapped Distribution for Drug Use in 2018 of '+ ageGroup +' Year Olds'))
    plt.show()

# %%
numOfBootstrappedCounts = 1000 # number of samples to take 

props = bootstrap(virtualG1, numOfBootstrappedCounts) # get sample counts by bootstrapping 
tailsHisto(props, 13, .05, '12-17') # plot distribution with CI cutoff values 
low, high = confidenceIntervals(props) # get exact confidence interval values 
print('5% Confidence Interval Cutoff Values:', low, high)

props = bootstrap(virtualG3, numOfBootstrappedCounts) # get sample counts by bootstrapping 
tailsHisto(props, 14, .05, '26+') # plot distribution with CI cutoff values 
low, high = confidenceIntervals(props) # get exact confidence interval values 
print('5% Confidence Interval Cutoff Values:', low, high)
# Out:
# 5% Confidence Interval Cutoff Values: 809.0 923.0
# 5% Confidence Interval Cutoff Values: 1115.0 1245.0

# %% [markdown]
# FIGURES 2-3: The above 2 plots are the sampling distributions created for two age groups by bootstrapping their drug use proportion data from 2018. The age group represented by each plot is specified in the plot title.
# <li> The ratio of drug users per 1,530,000 18-25 year olds in 2018 was 2715 users.
# <li> The 5% confidence interval cut off values for each distribution are printed beneath the corresponding plot.

# %% [markdown]
# ### Which age range had the most drug-positive drivers?
# Hypothesis: 21-34 year olds had the highest frequency of drug-positive crash drivers.

# %%
# frequency of drug-positive crashes in each age group
fig = plt.figure(figsize=(6, 5)) # initializing plot 
ax = plt.axes() 
plt.bar(ageGroups2, ageGroupCounts, color='purple') # displayed in a bar graph
ax.set_title('Frequency of Drug-Positive Crashes for Various Age Groups')
ax.set_xlabel('Age Range')
ax.set_ylabel('Number of Drivers')
# Out:
# Text(0, 0.5, 'Number of Drivers')

# %% [markdown]
# FIGURE 4: The above plot shows the number of drug-positive crash drivers in 4 age groups.

# %% [markdown]
# ### Which drug was the most likely to be used by each age group?
#
# Hypothesis: Alcohol had the highest usage in every age group.

# %%
fig, axs = plt.subplots(3,figsize=(8,12)) # initializing plot 
fig.suptitle('Comparing Drug Use Rates of Various Drugs Overtime', size=15) # adding overall title

# 12-17 year olds per drug usage overtime
axs[0].plot(years, alcoholG1, color='red', label='Alcohol') # first line in line graph 
axs[0].plot(years, cocaineG1, color='blue', label='Cocaine') # second line in line graph 
axs[0].plot(years, marijuanaG1, color='green', label='Marijuana') # third line in line graph 
axs[0].set_title('12-17 Year Olds', size=12)
axs[0].set_ylabel('Number of Users')
axs[0].legend(title='Drug', fontsize=9)

# 18-25 year olds per drug usage overtime
axs[1].plot(years, alcoholG2, color='red', label='Alcohol') # first line in line graph 
axs[1].plot(years, cocaineG2, color='blue', label='Cocaine') # second line in line graph 
axs[1].plot(years, marijuanaG2, color='green', label='Marijuana') # third line in line graph 
axs[1].set_title('18-25 Year Olds', size=12)
axs[1].set_ylabel('Number of Users')
axs[1].legend(title='Drug', fontsize=9)

# 26+ year olds per drug usage overtime
axs[2].plot(years, alcoholG3, color='red', label='Alcohol') # first line in line graph 
axs[2].plot(years, cocaineG3, color='blue', label='Cocaine') # second line in line graph 
axs[2].plot(years, marijuanaG3, color='green', label='Marijuana') # third line in line graph 
axs[2].set_title('26+ Year Olds', size=12)
axs[2].set_xlabel('Year')
axs[2].set_ylabel('Number of Users')
axs[2].legend(title='Drug', fontsize=9)

# %% [markdown]
# FIGURE 5: The above three subplots show the number of people within an age group between 2010 and 2018 who were users of a certain drug. Each line represents a different drug, as specified in the legends.

# %% [markdown]
# ### Which drugs were most frequently found in drug-positive crash drivers?
# Hypothesis: Alcohol was the most frequently found drug in drug-positive crash drivers.

# %%
# sort values for clarity in graph 
dic = {} # dictionary with drug name as key and count as value 
for ii in range(len(uniqueDrugs)):
    dic[uniqueDrugs[ii]] = drugCounts[ii] # adding values to dictionary 
dic_sorted = dict(sorted(dic.items(), key=lambda item: item[1])) # sort dictionary by value (counts)

# frequency of each drug in drug-positive crash drivers, displayed in a bar graph
fig = plt.figure(figsize=(18,6)) # initialize plot
ax = plt.axes() 
plt.bar(dic_sorted.keys(), dic_sorted.values(), color='darkgreen') # using sorted dictionary keys and values 
ax.set_title('Frequency of Each Drug Found in Drug-Positive Crash Drivers', size=21)
ax.set_xlabel('Drug Name', fontsize=15)
ax.set_ylabel('Number of Drivers', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Drivers')

# %% [markdown]
# FIGURE 6: The above plot shows the frequency that different drugs were found in drug-positive crash drivers.

# %% [markdown]
# ## DISCUSSION

# %% [markdown]
# ### Individual Figure Analyses:
#
# Figure 1 shows that in 2018, 18-25 year olds had the highest rate of substance use of the three age groups, as predicted in my hypothesis. In order to determine if the substance use rate of 18-25 year olds in 2018 was significantly different from the use rates of the other two age groups, two bootstrap analyses were performed. The resulting sampling distributions are shown in Figures 2 and 3. These plots also show the 5% confidence interval cutoff values, as indicated by the red bars. The confidence interval for 12-17 year olds was 809-923 users (per 1,530,000 people) and that for 26+ year olds was 1115-1245 users (per 1,530,000 people). The rate of drug use for 18-25 year olds in 2018 was 2715 users (per 1,530,000 people). Since 2715 users is not in either of the sampling distributions’ confidence intervals, it can be concluded that the ratio of use for 18-25 year olds in 2018 was significantly higher than the ratios of use for the other age groups, thereby supporting my hypothesis.
#
# Figure 4 represents the quantity of drivers in 4 age groups who were drug-positive car crash drivers. It shows that the age group with the most crash drivers under the influence was 21-34 year olds, followed closely by 35-64 year olds. The 16-20 and 65+ age groups had the lowest count of impaired crash drivers. This result supports my hypothesis.
#
# Figure 5 shows the number of people within each age group who were users of a certain drug over time. From 2010 to 2018, marijuana was by far the most used drug among 12-17 and 18-25 year olds. However, these groups differ in marijuana use in that the number of 12-17 year old users decreased over time and the number of 18-25 year old users increased over time. Alcohol and cocaine were significantly less used in these groups. In contrast, alcohol and marijuana uses in 26+ year olds were comparable. From 2010 to 2015, alcohol was most used by this group but from 2015 to 2018, marijuana was most used by this group. These results disprove my hypthesis that alcohol would be the most used drug for all age groups.
#
# Figure 6 presents the frequencies that drugs were found in drug-positive car crash drivers. THC had by far the highest prevalence, followed by mixed doses, amphetamine, and alcohol. I had predicted that alcohol would have the highest frequency, so this conclusion contradicts my hypothesis.

# %% [markdown]
# ### Overall Analysis:
#
# Figures 2 and 3 prove that the rate of drug use for 18-25 year olds was significantly higher than the rates of use for other age groups in 2018 and Figure 4 signifies that 21-34 year olds were most likely to be drug-positive car crash drivers. These results correlate with each other to show that young adults, specifically people in their early 20s, are most at risk for substance abuse and for being in a car accident while under the influence. This conclusion makes sense as exposure to drug use and time spent driving might increase when an individual moves away from home or enters the professional world for the first time.
#
# Figure 5 demonstrates that the most used drug by 12-25 year olds between 2010 and 2018 was marijuana and that the number of marijuana users in the 18-25 age group had increased during this 8-year period. Marijuana also competed with alcohol as the most used drug by 26+ year olds. Figure 6 shows that THC was the most commonly found drug in crash drivers. These results combine to demonstrate that marijuana is both the most used drug by people in the US and most common drug found in impaired car crash drivers. The increasing use of marijuana in the US could potentially put more people in danger as crash-risk increases for these individuals.
#
# This analysis is limited by a couple factors. For one, the drug use data is for the US only, so those results can't necessarily be generalized to age groups and their drug usages throughout the world. In fact, drug use rates are likely to vary with location as accessibility and acceptance of certain drugs will vary with geographical and cultural differences. A second limitation is that the drug use data used here only considered alcohol, cocaine, and marijuana usage. These are likely the most commonly used substances so they should allow for an accurate comparison, but it is important to note that these rates don't encompass all drugs.
